# %%
import subprocess
result = subprocess.run(['python', '../src/preprocessing.py'], capture_output=True, text=True, cwd='C:/Users/mudas/race_rc_project/src')
print(result.stdout)
print(result.stderr)
# Out:
# Loading data...
# Parsing options...
# Extracting features...
# Train size after parsing: 66901
# Val size after parsing: 3696
# Test size after parsing: 3771
# Building OHE features...
# Encoding labels...
# Shapes:
# X_train: (66901, 500)
# X_val: (3696, 500)
# X_test: (3771, 500)
# Saving...
# Saved!
# Preprocessing complete!

# %%
import subprocess
import os

os.chdir('C:/Users/mudas/race_rc_project')

result1 = subprocess.run(['git', 'add', 'src/preprocessing.py', 'notebooks/preprocessing_run.ipynb'], capture_output=True, text=True)
result2 = subprocess.run(['git', 'commit', '-m', 'add preprocessing pipeline'], capture_output=True, text=True)
result3 = subprocess.run(['git', 'push'], capture_output=True, text=True)

print(result2.stdout)
print(result3.stdout)
print(result3.stderr)
# Out:
# [main f862468] add preprocessing pipeline
#  2 files changed, 213 insertions(+)
#  create mode 100644 notebooks/preprocessing_run.ipynb
#
#
# To https://github.com/mudassirs52/race_rc_project.git
#    b2458dc..f862468  main -> main
